# %%
from typing import List
class Solution:
    def plusOne(self, digits: List[int]) -> List[int]:
        string = ""
        for i in digits:
            string += str(i)
        string = str(int(string) + 1)
        return string

digits = [1,2,3]
obj = Solution()
print(type(obj.plusOne(digits)))
# Out:
# <class 'str'>

# %%
# Out:
# <class 'int'>
